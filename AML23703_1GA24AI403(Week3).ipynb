# %%
#Real-world:Use single-qubit gates to model a simple quantum coin-flip game and calculate win probabilities.

# %%
from qiskit import QuantumCircuit, transpile
from qiskit_aer import Aer

# %%
qc = QuantumCircuit(1, 1)

# %%
qc.h(0)

# %%
qc.measure(0, 0)

print("Quantum Coin Flip Circuit:")
print(qc)
# Out:
# Quantum Coin Flip Circuit:
#      ┌───┐┌─┐
#   q: ┤ H ├┤M├
#      └───┘└╥┘
# c: 1/══════╩═
#            0

# %%
simulator = Aer.get_backend("qasm_simulator")
compiled_circuit = transpile(qc, simulator)

result = simulator.run(compiled_circuit, shots=1000).result()

counts = result.get_counts()

print("\nMeasurement Results:")
print(counts)
# Out:
# Measurement Results:
# {'1': 485, '0': 515}

# %%
heads = counts.get('0', 0)
tails = counts.get('1', 0)

print("\nWin Probabilities:")
print(f"Heads (|0>): {heads/1000:.3f}")
print(f"Tails (|1>): {tails/1000:.3f}")
# Out:
# Win Probabilities:
# Heads (|0>): 0.515
# Tails (|1>): 0.485

# %%
#Challenge: Prove gate equivalencp — show that HZH (Hadamard-Z-Hadamard)is equivalent to the X gate, both analytically and via circuit simulation

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector

# %%
qc1 = QuantumCircuit(1)
qc1.h(0)
qc1.z(0)
qc1.h(0)

# %%
state1 = Statevector.from_instruction(qc1)

print("Circuit: HZH")
print(qc1)
print("\nStatevector (HZH):")
print(state1)
# Out:
# Circuit: HZH
#    ┌───┐┌───┐┌───┐
# q: ┤ H ├┤ Z ├┤ H ├
#    └───┘└───┘└───┘
#
# Statevector (HZH):
# Statevector([0.+0.j, 1.+0.j],
#             dims=(2,))

# %%
qc2 = QuantumCircuit(1)
qc2.x(0)

# %%
state2 = Statevector.from_instruction(qc2)

print("\nCircuit: X")
print(qc2)
print("\nStatevector (X):")
print(state2)
# Out:
# Circuit: X
#    ┌───┐
# q: ┤ X ├
#    └───┘
#
# Statevector (X):
# Statevector([0.+0.j, 1.+0.j],
#             dims=(2,))

# %%
print("\nAre the two statevectors equal?")
print(state1.equiv(state2))
# Out:
# Are the two statevectors equal?
# True
